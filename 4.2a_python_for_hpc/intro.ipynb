# %%
print("Hello world")

# %%
a = 3

# %%
a ** 2

# %% [markdown]
# # Python for HPC
#
# * dfsafds
# * fdsafdsaf
#
# $\int_{0}^{\infty} e^{-x^2} dx$

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,2])

# %%
hostname = !hostname

# %%
hostname

# %% [markdown]
# ### Check we are not on the login node

# %%
assert "login" not in hostname[0]

# %% [markdown]
# ### Check we are running inside the singularity container

# %%
import os

# %%
assert os.environ["SINGULARITY_CONTAINER"] == '/expanse/lustre/projects/sds166/zonca/dask-numba-si22.sif'
